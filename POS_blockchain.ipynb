# %%
from datetime import datetime
import time
from hashlib import sha256
import json, requests
from random import randint

# %%
DATE = datetime.now()
GENESIS_BLOCK = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}
GENESIS_BLOCK2 = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}
GENESIS_BLOCK3 = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}

GENESIS_BLOCK4 = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}

# %%
genesisblock = GENESIS_BLOCK

# %%
def generate_new_block(self, bpm=randint(53, 63), oldBlock='', address=''):
    if self.myCurrBlock:
        return self.myCurrBlock
    prevHash = self.blockChain[-1]['Hash']
    index = len(self.blockChain) if not oldBlock else oldBlock['Index'] + 1
    address =  self.get_validator(self.myAccount) if not address else address
    newBlock = {
        "Index": index,
        "Timestamp": str(datetime.now()),
        "BPM": bpm, #instead of transactions
        "PrevHash": prevHash,
        "Validator": address
    }
    newBlock["Hash"] = self.hasher(newBlock)
    assert self.is_block_valid(newBlock)
    self.myCurrBlock = newBlock
    return newBlock

# %%
genesisblock['Timestamp']
# Out:
# '2022-07-11 09:24:18.864401'

# %%
if not genesisblock['Timestamp'] :
    print("s")

# %%
GENESIS_BLOCK5 = {}

# %%
generate_genesis_block(GENESIS_BLOCK4)
# Out:
# {'Index': 0,
#  'Timestamp': '2022-07-11 09:24:18.864401',
#  'BPM': 0,
#  'PrevHash': '0000000000000000',
#  'Validator': 'eltneg, 50, 0',
#  'Hash': '21b6fcaa0ad5e811fb35868cf29faa33436a4ffd5a2fa64e95ed860be38a3908'}

# %%
def generate_genesis_block(genesisblock):
    address = {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
    address = get_validator(address)
    genesisblock['Index'] = 0   #  if genesisblock['Index'] == 0 else genesisblock['Index']
    genesisblock['Timestamp'] = str(datetime.now()) if not genesisblock['Timestamp'] else genesisblock['Timestamp']
    genesisblock['BPM'] = 0 if not genesisblock['BPM'] else genesisblock['BPM']
    genesisblock['PrevHash'] = '0000000000000000'
    genesisblock['Validator'] = address if not genesisblock['Validator'] else genesisblock['Validator']
    genesisblock['Hash'] = hasher(genesisblock)
    return genesisblock  


def get_validator(address):
    return ', '.join([address['Address'], str(address['Weight']), str(address['Age'])])

def hasher(block):
    block_string = json.dumps(block, sort_keys=True).encode()
    return sha256(block_string).hexdigest()

# %%
class Blockchain(object):
    def __init__(self, _genesisBlock, account):
        """
            If the genesis block is valid, create chain
        """
        self.blockChain = []
        self.tempBlocks = []
        #self.candidateBlocks = [] #constains block
        self.myCurrBlock = {}
        #self.announcements = []
        self.validators = set() # stakers and balance
        #self.unconfirmed_txns = []
        self.nodes = set()
        self.myAccount = {'Address': '', 'Weight': 0, 'Age': 0}
        self.myAccount['Address'] = account['Address']
        self.myAccount['Weight'] = account['Weight']
        try:
            genesisBlock = self.generate_genesis_block(_genesisBlock)
            if self.is_block_valid(genesisBlock):
                self.blockChain.append(genesisBlock)
            else:
                raise Exception('Unable to verify block')
        except Exception as e:
            print('Invalid genesis block.\nOR\n' + str(e))
    
    @staticmethod
    def get_validator(address):
        return ', '.join([address['Address'], str(address['Weight']), str(address['Age'])])
    
    @staticmethod
    def hasher(block):
        block_string = json.dumps(block, sort_keys=True).encode()
        return sha256(block_string).hexdigest()
    
    def generate_genesis_block(self, genesisblock):
        address = {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
        address = self.get_validator(address)
        genesisblock['Index'] = 0 if genesisblock['Index'] else genesisblock['Index']
        genesisblock['Timestamp'] = str(datetime.now()) if not genesisblock['Timestamp'] else genesisblock['Timestamp']
        genesisblock['BPM'] = 0 if not genesisblock['BPM'] else genesisblock['BPM']
        genesisblock['PrevHash'] = '0000000000000000'
        genesisblock['Validator'] = address if not genesisblock['Validator'] else genesisblock['Validator']
        genesisblock['Hash'] = self.hasher(genesisblock)
        return genesisblock       
    

    ## 내 블록을 해시 만들고, 넣기, 
    ## 전블록의 해시
    def is_block_valid(self, block, prevBlock={}):
        try:
            _hash = block.pop('Hash')
        except KeyError as e:
            return False
        try:
            hash2 = self.hasher(block)
            assert _hash == hash2
        except AssertionError as e:
            return False
            
        prevHash = prevBlock['Hash'] if prevBlock else ''
        block['Hash'] = _hash
        if self.blockChain:
            prevHash = self.blockChain[-1]['Hash'] if not prevHash else prevHash
            if prevHash == block["PrevHash"]:
                1==1
            else:
                if prevHash == self.blockChain[0]['Hash']:
                    block['Hash'] = _hash
                    return True                    
                block['Hash'] = _hash
                return False            
        block['Hash'] = _hash
        return True

# %%
if '':
    print("ASd")

# %%
GENESIS_BLOCK
# Out:
# {'Index': 0,
#  'Timestamp': '2022-07-11 09:31:20.828090',
#  'BPM': 0,
#  'PrevHash': '0000000000000000',
#  'Validator': 'eltneg, 50, 0',
#  'Hash': 'e06ccf647fa16d5264c76f49cb814d1a2be2afb5aeae3552b481eee76874c1a8'}

# %%
GENESIS_BLOCK.pop("Timestamp")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2343585/3422120149.py in <module>
# ----> 1 GENESIS_BLOCK.pop("Timestamp")
#
# KeyError: 'Timestamp'

# %%
aaa = {}
if aaa:
    print("!")

# %%
account = {'Address': 'eltneg', 'Weight': 50}
a = Blockchain(GENESIS_BLOCK, account)

# %%
a.blockChain
# Out:
# [{'Index': 0,
#   'Timestamp': '2022-06-27 10:07:09.011866',
#   'BPM': 0,
#   'PrevHash': '0000000000000000',
#   'Validator': 'eltneg, 50, 0',
#   'Hash': 'c5088c999aaf80a7aaae0c54542533a13c658405f1e172e8bae88ed4faf98d9a'}]

# %%
class Blockchain(object):
    

    def __init__(self, _genesisBlock, account):
        """
            If the genesis block is valid, create chain
        """
        self.blockChain = []
        self.tempBlocks = []
        #self.candidateBlocks = [] #constains block
        self.myCurrBlock = {}
        #self.announcements = []
        self.validators = set() # stakers and balance
        #self.unconfirmed_txns = []
        self.nodes = set()
        self.myAccount = {'Address': '', 'Weight': 0, 'Age': 0}
        self.myAccount['Address'] = account['Address']
        self.myAccount['Weight'] = account['Weight']
        try:
            genesisBlock = self.generate_genesis_block(_genesisBlock)
            if self.is_block_valid(genesisBlock):
                self.blockChain.append(genesisBlock)
            else:
                raise Exception('Unable to verify block')
        except Exception as e:
            print('Invalid genesis block.\nOR\n' + str(e))

    def is_block_valid(self, block, prevBlock={}):
        try:
            _hash = block.pop('Hash')
        except KeyError as e:
            return False
        try:
            hash2 = self.hasher(block)
            assert _hash == hash2
        except AssertionError as e:
            return False
            
        prevHash = prevBlock['Hash'] if prevBlock else ''
        block['Hash'] = _hash
        if self.blockChain:
            prevHash = self.blockChain[-1]['Hash'] if not prevHash else prevHash
            try:
                assert prevHash == block["PrevHash"]
            except AssertionError as e:
                if prevHash == self.blockChain[0]['Hash']:
                    block['Hash'] = _hash
                    return True
                block['Hash'] = _hash
                return False
        block['Hash'] = _hash
        return True

    def generate_new_block(self, bpm=randint(53, 63), oldBlock='', address=''):
        if self.myCurrBlock:
            return self.myCurrBlock
        prevHash = self.blockChain[-1]['Hash']
        index = len(self.blockChain) if not oldBlock else oldBlock['Index'] + 1
        address =  self.get_validator(self.myAccount) if not address else address
        newBlock = {
            "Index": index,
            "Timestamp": str(datetime.now()),
            "BPM": bpm, #instead of transactions
            "PrevHash": prevHash,
            "Validator": address
        }
        newBlock["Hash"] = self.hasher(newBlock)
        assert self.is_block_valid(newBlock)
        self.myCurrBlock = newBlock
        return newBlock

    def get_blocks_from_nodes(self):
        if self.nodes:
            for node in self.nodes:
                #resp = requests.get('http://{}/newblock'.format(node))
                node.add_another_block(self.myCurrBlock)
                resp = node.generate_new_block()
                if self.is_block_valid(resp): #resp.json()
                    #self.tempBlocks.append(resp.json())
                    if not resp['Validator'] in self.validators:
                        self.tempBlocks.append(resp)
                        self.validators.add(resp['Validator'])

    def add_another_block(self, another_block):
        if self.is_block_valid(another_block):
            if not another_block['Validator'] in self.validators:
                self.tempBlocks.append(another_block)
                self.validators.add(another_block['Validator'])


    def pick_winner(self):
        """Creates a lottery pool of validators and choose the validator
            who gets to forge the next block. Random selection weighted by amount of token staked
            Do this every 30 seconds
        """
        winner = []

        self.tempBlocks.append(self.myCurrBlock)
        self.validators.add(self.myCurrBlock['Validator'])
        for validator in self.validators:
            acct = (validator.rsplit(sep=', '))
            acct.append(int(acct[1]) * int(acct[2]))
            if winner and acct[-1]:
                winner = acct if winner[-1] < acct[-1] else winner
            else:
                winner = acct if acct[-1] else winner
        if winner:
            return winner
        for validator in self.validators:
            acct = (validator.rsplit(sep=', '))
            acct.append((int(acct[1]) + int(acct[2]))/len(acct[0]))
            if winner:
                winner = acct if winner[-1] < acct[-1] else winner
            else:
                winner = acct
        return winner

    def pos(self):
        """
        #get other's stakes
        #add owns claim
        #pick winner
        """

        print(str(self.myAccount) + ' =======================> Getting Valid chain\n')
        self.resolve_conflict()
        time.sleep(1)
        self._pos()
        print('***Calling other nodes to announce theirs***' + "\n")
        time.sleep(1)
        for node in self.nodes:
            node._pos()
        time.sleep(1)
        for block in self.tempBlocks:
            validator = block['Validator'].rsplit(', ')
            if validator[0] == self.pick_winner()[0]:
                new_block = block
                break
            else:
                pass
        print('New Block ====> ' + str(new_block) + "\n")
        time.sleep(1)
        self.add_new_block(new_block)
        for node in self.nodes:
            node.add_new_block(new_block)
        print('Process ends' + "\n")
        
    def announce_winner(self):
        self.blockChain.append(self.myCurrBlock)

    def add_new_block(self, block):
        if self.is_block_valid(block):
            #check index too
            self.blockChain.append(block)
            acct = block['Validator'].rsplit(', ')
            if self.myAccount['Address'] != acct[0]:
                self.myAccount['Age'] += 1
            else:
                self.myAccount['Weight'] += (randint(1, 10) * self.myAccount['Age'])
                self.myAccount['Age'] = 0
        self.tempBlocks = []
        self.myCurrBlock = {}
        self.validators = set()



    def _pos(self):
        print("Coming from ==========================> " + str(self.myAccount) + "\n")
        time.sleep(1)
        print('***Generating new stake block***' + "\n")
        time.sleep(1)
        self.generate_new_block()
        print('***Exchanging temporary blocks with other nodes***' + "\n")
        time.sleep(1)
        self.get_blocks_from_nodes()
        print('***Picking a winner***' + "\n")
        time.sleep(1)
        print("Winner is =======================> " + str(self.pick_winner()) + "\n")
    
    def resolve_conflict(self):
        for node in self.nodes:
            if len(node.blockChain) > len(self.blockChain):
                if self.is_chain_valid(node.blockChain):
                    print('***Replacing node***' + "\n")
                    self.blockChain = node.blockChain
                    return
        print('***My chain is authoritative***' + "\n")
        return

    def is_chain_valid(self, chain):
        _prevBlock = ''
        for block in chain:
            if self.is_block_valid(block, prevBlock=_prevBlock):
                _prevBlock = block
            else:
                return False
        return True


    def add_new_node(self, new_node):
        self.nodes.add(new_node)
        new_node.add_another_node(self)

    def add_another_node(self, another_node):
        self.nodes.add(another_node)

    @staticmethod
    def hasher(block):
        block_string = json.dumps(block, sort_keys=True).encode()
        return sha256(block_string).hexdigest()

    @staticmethod
    def get_validator(address):
        return ', '.join([address['Address'], str(address['Weight']), str(address['Age'])])

    def generate_genesis_block(self, genesisblock):
        address = {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
        address = self.get_validator(address)
        genesisblock['Index'] = 0 if not genesisblock['Index'] else genesisblock['Index']
        genesisblock['Timestamp'] = str(datetime.now()) if not genesisblock['Timestamp'] else genesisblock['Timestamp']
        genesisblock['BPM'] = 0 if not genesisblock['BPM'] else genesisblock['BPM']
        genesisblock['PrevHash'] = '0000000000000000'
        genesisblock['Validator'] = address if not genesisblock['Validator'] else genesisblock['Validator']
        genesisblock['Hash'] = self.hasher(genesisblock)
        return genesisblock       

def main():
    """Run test"""
    account = {'Address': 'eltneg', 'Weight': 50}
    account2 = {'Address': 'account2', 'Weight': 55}
    account3 = {'Address': 'account3', 'Weight': 43}
    account4 = {'Address': 'account4', 'Weight': 16}
    blockchain = Blockchain(GENESIS_BLOCK, account)
    blockchain.generate_new_block(52)

    blockchain2 = Blockchain(GENESIS_BLOCK2, account2)
    blockchain3 = Blockchain(GENESIS_BLOCK3, account3)

    clients = [blockchain, blockchain2, blockchain3]
    
    blockchain.add_new_node(blockchain2)
    blockchain.add_new_node(blockchain3)

    blockchain2.add_new_node(blockchain)
    blockchain2.add_new_node(blockchain3)

    blockchain.get_blocks_from_nodes()
    blockchain2.get_blocks_from_nodes()

    blockchain.pick_winner()
    #check if temp blocks are same

    blockchain.pos()
    blockchain2.pos()
    blockchain3.pos()

    blockchain4 = Blockchain(GENESIS_BLOCK4, account4)
    blockchain4.add_new_node(blockchain)
    blockchain4.add_new_node(blockchain2)
    blockchain4.add_new_node(blockchain3)
    blockchain4.pos()
    clients.append(blockchain4)
    while True:
        print('============================================ \n\n')
        client = clients[randint(0, 3)]
        client.pos()
        time.sleep(3)

# %%
account = {'Address': 'eltneg', 'Weight': 50}
account2 = {'Address': 'account2', 'Weight': 55}
account3 = {'Address': 'account3', 'Weight': 43}
account4 = {'Address': 'account4', 'Weight': 16}
blockchain = Blockchain(GENESIS_BLOCK, account)
blockchain.generate_new_block(52)


blockchain2 = Blockchain(GENESIS_BLOCK2, account2)
blockchain3 = Blockchain(GENESIS_BLOCK3, account3)

clients = [blockchain, blockchain2, blockchain3]


blockchain.add_new_node(blockchain2)
blockchain.add_new_node(blockchain3)

blockchain2.add_new_node(blockchain)
blockchain2.add_new_node(blockchain3)

blockchain.get_blocks_from_nodes()
blockchain2.get_blocks_from_nodes()

blockchain.pick_winner()
# Out:
# {'Index': 1,
#  'Timestamp': '2022-07-04 19:43:12.080075',
#  'BPM': 52,
#  'PrevHash': 'b06af744441edec1dbd168f917a65c889bf617880f636e5854a500a524076dc8',
#  'Validator': 'eltneg, 50, 0',
#  'Hash': '7b828a2aecadf4a4ac171bbd676892ef348f9b8c16092711b302a4bc1b7d8d2a'}

# %%
blockchain.pos()
# Out:
# {'Address': 'eltneg', 'Weight': 50, 'Age': 0} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '0', 8.333333333333334]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '0', 8.333333333333334]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 55, 'Age': 0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3141/1621808737.py in <module>
# ----> 1 blockchain.pos()
#
# /tmp/ipykernel_3141/2687947036.py in pos(self)
#     130         time.sleep(1)
#     131         for node in self.nodes:
# --> 132             node._pos()
#     133         time.sleep(1)
#     134         for block in self.tempBlocks:
#
# /tmp/ipykernel_3141/2687947036.py in _pos(self)
#     167     def _pos(self):
#     168         print("Coming from ==========================> " + str(self.myAccount) + "\n")
# --> 169         time.sleep(1)
#     170         print('***Generating new stake block***' + "\n")
#     171         time.sleep(1)
#
# KeyboardInterrupt:

# %%
GENESIS_BLOCK
# Out:
# {'Index': 0,
#  'Timestamp': '2022-07-04 19:42:51.088689',
#  'BPM': 0,
#  'PrevHash': '0000000000000000',
#  'Validator': 'eltneg, 50, 0',
#  'Hash': 'b06af744441edec1dbd168f917a65c889bf617880f636e5854a500a524076dc8'}

# %%
blockchain2.block
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3141/1746335381.py in <module>
# ----> 1 blockchain2.block
#
# AttributeError: 'Blockchain' object has no attribute 'block'

# %%
blockchain4 = Blockchain(GENESIS_BLOCK4, account4)
blockchain4.add_new_node(blockchain)
blockchain4.add_new_node(blockchain2)
blockchain4.add_new_node(blockchain3)clients.append(blockchain4)

# %%
clients.append(blockchain4)

# %%
while True:
    print('============================================ \n\n')
    client = clients[randint(0, 3)]
    client.pos()
# Out:
# ============================================
#
#
# {'Address': 'account3', 'Weight': 43, 'Age': 1} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 55, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# New Block ====> {'Index': 2, 'Timestamp': '2022-07-04 19:49:16.573474', 'BPM': 62, 'PrevHash': '7b828a2aecadf4a4ac171bbd676892ef348f9b8c16092711b302a4bc1b7d8d2a', 'Validator': 'account2, 55, 1', 'Hash': '80c218b4533694a1ef2c5bee2a079cdfaf3c3867db6f5aadf4230946ebb08621'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account3', 'Weight': 43, 'Age': 2} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 58, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# New Block ====> {'Index': 3, 'Timestamp': '2022-07-04 19:51:08.805703', 'BPM': 62, 'PrevHash': '80c218b4533694a1ef2c5bee2a079cdfaf3c3867db6f5aadf4230946ebb08621', 'Validator': 'account3, 43, 2', 'Hash': 'c31e256eedb66898a6579658fe22a42d0e5cc2dd7c5cc6faac8d02ae737cd107'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account3', 'Weight': 53, 'Age': 0} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 53, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 3}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 58, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# New Block ====> {'Index': 4, 'Timestamp': '2022-07-04 19:51:29.844877', 'BPM': 62, 'PrevHash': 'c31e256eedb66898a6579658fe22a42d0e5cc2dd7c5cc6faac8d02ae737cd107', 'Validator': 'eltneg, 50, 2', 'Hash': '231a6f877eb251a630fd77867b36bb1c81e226dfba374cc802616414f5d10162'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account4', 'Weight': 16, 'Age': 4} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 4}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '58', '2', 116]
#
# ***Calling other nodes to announce theirs***
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3141/3752827410.py in <module>
#       2     print('============================================ \n\n')
#       3     client = clients[randint(0, 3)]
# ----> 4     client.pos()
#
# /tmp/ipykernel_3141/2687947036.py in pos(self)
#     128         self._pos()
#     129         print('***Calling other nodes to announce theirs***' + "\n")
# --> 130         time.sleep(1)
#     131         for node in self.nodes:
#     132             node._pos()
#
# KeyboardInterrupt:

# %%
blockchain.blockChain
# Out:
# [{'Index': 0,
#   'Timestamp': '2022-07-04 19:42:51.088689',
#   'BPM': 0,
#   'PrevHash': '0000000000000000',
#   'Validator': 'eltneg, 50, 0',
#   'Hash': 'b06af744441edec1dbd168f917a65c889bf617880f636e5854a500a524076dc8'},
#  {'Index': 1,
#   'Timestamp': '2022-07-04 19:43:12.080075',
#   'BPM': 52,
#   'PrevHash': 'b06af744441edec1dbd168f917a65c889bf617880f636e5854a500a524076dc8',
#   'Validator': 'eltneg, 50, 0',
#   'Hash': '7b828a2aecadf4a4ac171bbd676892ef348f9b8c16092711b302a4bc1b7d8d2a'},
#  {'Index': 2,
#   'Timestamp': '2022-07-04 19:49:16.573474',
#   'BPM': 62,
#   'PrevHash': '7b828a2aecadf4a4ac171bbd676892ef348f9b8c16092711b302a4bc1b7d8d2a',
#   'Validator': 'account2, 55, 1',
#   'Hash': '80c218b4533694a1ef2c5bee2a079cdfaf3c3867db6f5aadf4230946ebb08621'},
#  {'Index': 3,
#   'Timestamp': '2022-07-04 19:51:08.805703',
#   'BPM': 62,
#   'PrevHash': '80c218b4533694a1ef2c5bee2a079cdfaf3c3867db6f5aadf4230946ebb08621',
#   'Validator': 'account3, 43, 2',
#   'Hash': 'c31e256eedb66898a6579658fe22a42d0e5cc2dd7c5cc6faac8d02ae737cd107'},
#  {'Index': 4,
#   'Timestamp': '2022-07-04 19:51:29.844877',
#   'BPM': 62,
#   'PrevHash': 'c31e256eedb66898a6579658fe22a42d0e5cc2dd7c5cc6faac8d02ae737cd107',
#   'Validator': 'eltneg, 50, 2',
#   'Hash': '231a6f877eb251a630fd77867b36bb1c81e226dfba374cc802616414f5d10162'}]

# %%
def hasher(block):
    block_string = json.dumps(block, sort_keys=True).encode()
    return sha256(block_string).hexdigest()

# %%
hasher({'Index': 1,
  'Timestamp': '2022-07-04 19:43:12.080075',
  'BPM': 52,
  'PrevHash': 'b06af744441edec1dbd168f917a65c889bf617880f636e5854a500a524076dc8',
  'Validator': 'eltneg, 50, 0',
  'Hash': '7b828a2aecadf4a4ac171bbd676892ef348f9b8c16092711b302a4bc1b7d8d2a'})
# Out:
# '8ac82df6a12cec6a0d7c9b5962a57be7e861caa13a042056b1690ba51424483b'

# %%
blockchain2.blockChain
# Out:
# [{'Index': 0,
#   'Timestamp': '2022-07-04 19:42:51.088689',
#   'BPM': 0,
#   'PrevHash': '0000000000000000',
#   'Validator': 'eltneg, 50, 0',
#   'Hash': 'b06af744441edec1dbd168f917a65c889bf617880f636e5854a500a524076dc8'},
#  {'Index': 1,
#   'Timestamp': '2022-07-04 19:43:12.080075',
#   'BPM': 52,
#   'PrevHash': 'b06af744441edec1dbd168f917a65c889bf617880f636e5854a500a524076dc8',
#   'Validator': 'eltneg, 50, 0',
#   'Hash': '7b828a2aecadf4a4ac171bbd676892ef348f9b8c16092711b302a4bc1b7d8d2a'},
#  {'Index': 2,
#   'Timestamp': '2022-07-04 19:49:16.573474',
#   'BPM': 62,
#   'PrevHash': '7b828a2aecadf4a4ac171bbd676892ef348f9b8c16092711b302a4bc1b7d8d2a',
#   'Validator': 'account2, 55, 1',
#   'Hash': '80c218b4533694a1ef2c5bee2a079cdfaf3c3867db6f5aadf4230946ebb08621'},
#  {'Index': 3,
#   'Timestamp': '2022-07-04 19:51:08.805703',
#   'BPM': 62,
#   'PrevHash': '80c218b4533694a1ef2c5bee2a079cdfaf3c3867db6f5aadf4230946ebb08621',
#   'Validator': 'account3, 43, 2',
#   'Hash': 'c31e256eedb66898a6579658fe22a42d0e5cc2dd7c5cc6faac8d02ae737cd107'},
#  {'Index': 4,
#   'Timestamp': '2022-07-04 19:51:29.844877',
#   'BPM': 62,
#   'PrevHash': 'c31e256eedb66898a6579658fe22a42d0e5cc2dd7c5cc6faac8d02ae737cd107',
#   'Validator': 'eltneg, 50, 2',
#   'Hash': '231a6f877eb251a630fd77867b36bb1c81e226dfba374cc802616414f5d10162'}]

# %%
"""
    Python implementation of POW
    Credit: https://github.com/mycoralhealth/blockchain-tutorial
"""
from datetime import datetime
import time
from hashlib import sha256
import json, requests
from random import randint


DATE = datetime.now()
GENESIS_BLOCK = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}
GENESIS_BLOCK2 = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}
GENESIS_BLOCK3 = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}

GENESIS_BLOCK4 = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}


class Blockchain(object):
    

    def __init__(self, _genesisBlock, account):
        """
            If the genesis block is valid, create chain
        """
        self.blockChain = []
        self.tempBlocks = []
        #self.candidateBlocks = [] #constains block
        self.myCurrBlock = {}
        #self.announcements = []
        self.validators = set() # stakers and balance
        #self.unconfirmed_txns = []
        self.nodes = set()
        self.myAccount = {'Address': '', 'Weight': 0, 'Age': 0}
        self.myAccount['Address'] = account['Address']
        self.myAccount['Weight'] = account['Weight']
        try:
            genesisBlock = self.generate_genesis_block(_genesisBlock)
            if self.is_block_valid(genesisBlock):
                self.blockChain.append(genesisBlock)
            else:
                raise Exception('Unable to verify block')
        except Exception as e:
            print('Invalid genesis block.\nOR\n' + str(e))

    def is_block_valid(self, block, prevBlock={}):
        try:
            _hash = block.pop('Hash')
        except KeyError as e:
            return False
        try:
            hash2 = self.hasher(block)
            assert _hash == hash2
        except AssertionError as e:
            return False
            
        prevHash = prevBlock['Hash'] if prevBlock else ''
        block['Hash'] = _hash
        if self.blockChain:
            prevHash = self.blockChain[-1]['Hash'] if not prevHash else prevHash
            try:
                assert prevHash == block["PrevHash"]
            except AssertionError as e:
                if prevHash == self.blockChain[0]['Hash']:
                    block['Hash'] = _hash
                    return True
                block['Hash'] = _hash
                return False
        block['Hash'] = _hash
        return True

    def generate_new_block(self, bpm=randint(53, 63), oldBlock='', address=''):
        if self.myCurrBlock:
            return self.myCurrBlock
        prevHash = self.blockChain[-1]['Hash']
        index = len(self.blockChain) if not oldBlock else oldBlock['Index'] + 1
        address =  self.get_validator(self.myAccount) if not address else address
        newBlock = {
            "Index": index,
            "Timestamp": str(datetime.now()),
            "BPM": bpm, #instead of transactions
            "PrevHash": prevHash,
            "Validator": address
        }
        newBlock["Hash"] = self.hasher(newBlock)
        assert self.is_block_valid(newBlock)
        self.myCurrBlock = newBlock
        return newBlock

    def get_blocks_from_nodes(self):
        if self.nodes:
            for node in self.nodes:
                #resp = requests.get('http://{}/newblock'.format(node))
                node.add_another_block(self.myCurrBlock)
                resp = node.generate_new_block()
                if self.is_block_valid(resp): #resp.json()
                    #self.tempBlocks.append(resp.json())
                    if not resp['Validator'] in self.validators:
                        self.tempBlocks.append(resp)
                        self.validators.add(resp['Validator'])

    def add_another_block(self, another_block):
        if self.is_block_valid(another_block):
            if not another_block['Validator'] in self.validators:
                self.tempBlocks.append(another_block)
                self.validators.add(another_block['Validator'])


    def pick_winner(self):
        """Creates a lottery pool of validators and choose the validator
            who gets to forge the next block. Random selection weighted by amount of token staked

            Do this every 30 seconds
        """
        winner = []

        self.tempBlocks.append(self.myCurrBlock)
        self.validators.add(self.myCurrBlock['Validator'])
        for validator in self.validators:
            acct = (validator.rsplit(sep=', '))
            acct.append(int(acct[1]) * int(acct[2]))
            if winner and acct[-1]:
                winner = acct if winner[-1] < acct[-1] else winner
            else:
                winner = acct if acct[-1] else winner
        if winner:
            return winner
        for validator in self.validators:
            acct = (validator.rsplit(sep=', '))
            acct.append((int(acct[1]) + int(acct[2]))/len(acct[0]))
            if winner:
                winner = acct if winner[-1] < acct[-1] else winner
            else:
                winner = acct
        return winner

    def pos(self):
        """
        #get other's stakes
        #add owns claim
        #pick winner
        """

        print(str(self.myAccount) + ' =======================> Getting Valid chain\n')
        self.resolve_conflict()
        time.sleep(1)
        self._pos()
        print('***Calling other nodes to announce theirs***' + "\n")
        time.sleep(1)
        for node in self.nodes:
            node._pos()
        time.sleep(1)
        for block in self.tempBlocks:
            validator = block['Validator'].rsplit(', ')
            if validator[0] == self.pick_winner()[0]:
                new_block = block
                break
            else:
                pass
        print('New Block ====> ' + str(new_block) + "\n")
        time.sleep(1)
        self.add_new_block(new_block)
        for node in self.nodes:
            node.add_new_block(new_block)
        print('Process ends' + "\n")
        
    def announce_winner(self):
        self.blockChain.append(self.myCurrBlock)

    def add_new_block(self, block):
        if self.is_block_valid(block):
            #check index too
            self.blockChain.append(block)
            acct = block['Validator'].rsplit(', ')
            if self.myAccount['Address'] != acct[0]:
                self.myAccount['Age'] += 1
            else:
                self.myAccount['Weight'] += (randint(1, 10) * self.myAccount['Age'])
                self.myAccount['Age'] = 0
        self.tempBlocks = []
        self.myCurrBlock = {}
        self.validators = set()



    def _pos(self):
        print("Coming from ==========================> " + str(self.myAccount) + "\n")
        time.sleep(1)
        print('***Generating new stake block***' + "\n")
        time.sleep(1)
        self.generate_new_block()
        print('***Exchanging temporary blocks with other nodes***' + "\n")
        time.sleep(1)
        self.get_blocks_from_nodes()
        print('***Picking a winner***' + "\n")
        time.sleep(1)
        print("Winner is =======================> " + str(self.pick_winner()) + "\n")
    
    def resolve_conflict(self):
        for node in self.nodes:
            if len(node.blockChain) > len(self.blockChain):
                if self.is_chain_valid(node.blockChain):
                    print('***Replacing node***' + "\n")
                    self.blockChain = node.blockChain
                    return
        print('***My chain is authoritative***' + "\n")
        return

    def is_chain_valid(self, chain):
        _prevBlock = ''
        for block in chain:
            if self.is_block_valid(block, prevBlock=_prevBlock):
                _prevBlock = block
            else:
                return False
        return True


    def add_new_node(self, new_node):
        self.nodes.add(new_node)
        new_node.add_another_node(self)

    def add_another_node(self, another_node):
        self.nodes.add(another_node)

    @staticmethod
    def hasher(block):
        block_string = json.dumps(block, sort_keys=True).encode()
        return sha256(block_string).hexdigest()

    @staticmethod
    def get_validator(address):
        return ', '.join([address['Address'], str(address['Weight']), str(address['Age'])])

    def generate_genesis_block(self, genesisblock):
        address = {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
        address = self.get_validator(address)
        genesisblock['Index'] = 0 if not genesisblock['Index'] else genesisblock['Index']
        genesisblock['Timestamp'] = str(datetime.now()) if not genesisblock['Timestamp'] else genesisblock['Timestamp']
        genesisblock['BPM'] = 0 if not genesisblock['BPM'] else genesisblock['BPM']
        genesisblock['PrevHash'] = '0000000000000000'
        genesisblock['Validator'] = address if not genesisblock['Validator'] else genesisblock['Validator']
        genesisblock['Hash'] = self.hasher(genesisblock)
        return genesisblock       

def main():
    """Run test"""
    account = {'Address': 'eltneg', 'Weight': 50}
    account2 = {'Address': 'account2', 'Weight': 55}
    account3 = {'Address': 'account3', 'Weight': 43}
    account4 = {'Address': 'account4', 'Weight': 16}
    blockchain = Blockchain(GENESIS_BLOCK, account)
    blockchain.generate_new_block(52)

    blockchain2 = Blockchain(GENESIS_BLOCK2, account2)
    blockchain3 = Blockchain(GENESIS_BLOCK3, account3)

    clients = [blockchain, blockchain2, blockchain3]
    
    blockchain.add_new_node(blockchain2)
    blockchain.add_new_node(blockchain3)

    blockchain2.add_new_node(blockchain)
    blockchain2.add_new_node(blockchain3)

    blockchain.get_blocks_from_nodes()
    blockchain2.get_blocks_from_nodes()

    blockchain.pick_winner()
    #check if temp blocks are same

    blockchain.pos()
    blockchain2.pos()
    blockchain3.pos()

    blockchain4 = Blockchain(GENESIS_BLOCK4, account4)
    blockchain4.add_new_node(blockchain)
    blockchain4.add_new_node(blockchain2)
    blockchain4.add_new_node(blockchain3)
    blockchain4.pos()
    clients.append(blockchain4)
    while True:
        print('============================================ \n\n')
        client = clients[randint(0, 3)]
        client.pos()

if __name__ == '__main__':
    main()
# Out:
# {'Address': 'eltneg', 'Weight': 50, 'Age': 0} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '0', 8.333333333333334]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 55, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '0', 8.333333333333334]
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '0', 8.333333333333334]
#
# New Block ====> {'Index': 1, 'Timestamp': '2022-07-11 09:29:27.410455', 'BPM': 52, 'PrevHash': '0c4655a8a457ea9007c12ddb1a13d037ac16cfb698d70d51a023dbd53928043f', 'Validator': 'eltneg, 50, 0', 'Hash': '801c9bd7de828728fee150b56a13865f3bd001eaefa26ab85d391aac1ae14ac6'}
#
# Process ends
#
# {'Address': 'account2', 'Weight': 55, 'Age': 1} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 55, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# New Block ====> {'Index': 2, 'Timestamp': '2022-07-11 09:29:46.429329', 'BPM': 57, 'PrevHash': '801c9bd7de828728fee150b56a13865f3bd001eaefa26ab85d391aac1ae14ac6', 'Validator': 'account2, 55, 1', 'Hash': 'df20d1e45a8b788715c87faba3caaae01a186adf42e5c2f9fba001e11e00e118'}
#
# Process ends
#
# {'Address': 'account3', 'Weight': 43, 'Age': 2} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 57, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# New Block ====> {'Index': 3, 'Timestamp': '2022-07-11 09:30:02.446570', 'BPM': 57, 'PrevHash': 'df20d1e45a8b788715c87faba3caaae01a186adf42e5c2f9fba001e11e00e118', 'Validator': 'account3, 43, 2', 'Hash': 'e5dc2894be4a5b14ddbdadb028265586e581ebc1e14cd6f9eddd1350cd4b7b7c'}
#
# Process ends
#
# {'Address': 'account4', 'Weight': 16, 'Age': 0} =======================> Getting Valid chain
#
# ***Replacing node***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 57, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 45, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# New Block ====> {'Index': 4, 'Timestamp': '2022-07-11 09:30:19.464459', 'BPM': 57, 'PrevHash': 'e5dc2894be4a5b14ddbdadb028265586e581ebc1e14cd6f9eddd1350cd4b7b7c', 'Validator': 'eltneg, 50, 2', 'Hash': 'be11bb10ac3921daaca0aabddad6a54cdb07f51840367077110947590c26bde5'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account2', 'Weight': 57, 'Age': 1} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 57, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '57', '1', 57]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '57', '1', 57]
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 45, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '57', '1', 57]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 66, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '57', '1', 57]
#
# New Block ====> {'Index': 5, 'Timestamp': '2022-07-11 09:30:38.485909', 'BPM': 57, 'PrevHash': 'be11bb10ac3921daaca0aabddad6a54cdb07f51840367077110947590c26bde5', 'Validator': 'account2, 57, 1', 'Hash': '31672f5b0756fdbeb0f143ecc2ab1af12ba1a0981de00ceb5006b01bdfd7dc82'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account3', 'Weight': 45, 'Age': 2} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 45, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '45', '2', 90]
#
# ***Calling other nodes to announce theirs***
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1718672/3708306477.py in <module>
#     311
#     312 if __name__ == '__main__':
# --> 313     main()
#
# /tmp/ipykernel_1718672/3708306477.py in main()
#     308         print('============================================ \n\n')
#     309         client = clients[randint(0, 3)]
# --> 310         client.pos()
#     311
#     312 if __name__ == '__main__':
#
# /tmp/ipykernel_1718672/3708306477.py in pos(self)
#     172         self._pos()
#     173         print('***Calling other nodes to announce theirs***' + "\n")
# --> 174         time.sleep(1)
#     175         for node in self.nodes:
#     176             node._pos()
#
# KeyboardInterrupt:

# %%
"""
    Python implementation of POW
    Credit: https://github.com/mycoralhealth/blockchain-tutorial
"""
from datetime import datetime
import time
from hashlib import sha256
import json, requests
from random import randint


DATE = datetime.now()
GENESIS_BLOCK = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}
GENESIS_BLOCK2 = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}
GENESIS_BLOCK3 = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}

GENESIS_BLOCK4 = {
    "Index": 0,
    "Timestamp": str(DATE),
    "BPM": 0, #instead of transactions
    "PrevHash": "",
    "Validator": "" #address to receive the reward {validator, weight, age}
}


class Blockchain(object):
    

    def __init__(self, _genesisBlock, account):
        """
            If the genesis block is valid, create chain
        """
        self.blockChain = []
        self.tempBlocks = []
        #self.candidateBlocks = [] #constains block
        self.myCurrBlock = {}
        #self.announcements = []
        self.validators = set() # stakers and balance
        #self.unconfirmed_txns = []
        self.nodes = set()
        self.myAccount = {'Address': '', 'Weight': 0, 'Age': 0}
        self.myAccount['Address'] = account['Address']
        self.myAccount['Weight'] = account['Weight']
        try:
            genesisBlock = self.generate_genesis_block(_genesisBlock)
            if self.is_block_valid(genesisBlock):
                self.blockChain.append(genesisBlock)
            else:
                raise Exception('Unable to verify block')
        except Exception as e:
            print('Invalid genesis block.\nOR\n' + str(e))

    def is_block_valid(self, block, prevBlock={}):
        try:
            _hash = block.pop('Hash')
        except KeyError as e:
            return False
        try:
            hash2 = self.hasher(block)
            assert _hash == hash2
        except AssertionError as e:
            return False
            
        prevHash = prevBlock['Hash'] if prevBlock else ''
        block['Hash'] = _hash
        if self.blockChain:
            prevHash = self.blockChain[-1]['Hash'] if not prevHash else prevHash
            try:
                assert prevHash == block["PrevHash"]
            except AssertionError as e:
                if prevHash == self.blockChain[0]['Hash']:
                    block['Hash'] = _hash
                    return True
                block['Hash'] = _hash
                return False
        block['Hash'] = _hash
        return True

    def generate_new_block(self, bpm=randint(53, 63), oldBlock='', address=''):
        if self.myCurrBlock:
            return self.myCurrBlock
        prevHash = self.blockChain[-1]['Hash']
        index = len(self.blockChain) if not oldBlock else oldBlock['Index'] + 1
        address =  self.get_validator(self.myAccount) if not address else address
        newBlock = {
            "Index": index,
            "Timestamp": str(datetime.now()),
            "BPM": bpm, #instead of transactions
            "PrevHash": prevHash,
            "Validator": address
        }
        newBlock["Hash"] = self.hasher(newBlock)
        assert self.is_block_valid(newBlock)
        self.myCurrBlock = newBlock
        return newBlock

    def get_blocks_from_nodes(self):
        if self.nodes:
            for node in self.nodes:
                #resp = requests.get('http://{}/newblock'.format(node))
                node.add_another_block(self.myCurrBlock)
                resp = node.generate_new_block()
                if self.is_block_valid(resp): #resp.json()
                    #self.tempBlocks.append(resp.json())
                    if not resp['Validator'] in self.validators:
                        self.tempBlocks.append(resp)
                        self.validators.add(resp['Validator'])

    def add_another_block(self, another_block):
        if self.is_block_valid(another_block):
            if not another_block['Validator'] in self.validators:
                self.tempBlocks.append(another_block)
                self.validators.add(another_block['Validator'])


    def pick_winner(self):
        """Creates a lottery pool of validators and choose the validator
            who gets to forge the next block. Random selection weighted by amount of token staked

            Do this every 30 seconds
        """
        winner = []

        self.tempBlocks.append(self.myCurrBlock)
        self.validators.add(self.myCurrBlock['Validator'])
        for validator in self.validators:
            acct = (validator.rsplit(sep=', '))
            acct.append(int(acct[1]) * int(acct[2]))
            if winner and acct[-1]:
                winner = acct if winner[-1] < acct[-1] else winner
            else:
                winner = acct if acct[-1] else winner
        if winner:
            return winner
        for validator in self.validators:
            acct = (validator.rsplit(sep=', '))
            acct.append((int(acct[1]) + int(acct[2]))/len(acct[0]))
            if winner:
                winner = acct if winner[-1] < acct[-1] else winner
            else:
                winner = acct
        return winner

    def pos(self):
        """
        #get other's stakes
        #add owns claim
        #pick winner
        """

        print(str(self.myAccount) + ' =======================> Getting Valid chain\n')
        self.resolve_conflict()
        time.sleep(1)
        self._pos()
        print('***Calling other nodes to announce theirs***' + "\n")
        time.sleep(1)
        for node in self.nodes:
            node._pos()
        time.sleep(1)
        for block in self.tempBlocks:
            validator = block['Validator'].rsplit(', ')
            if validator[0] == self.pick_winner()[0]:
                new_block = block
                break
            else:
                pass
        print('New Block ====> ' + str(new_block) + "\n")
        time.sleep(1)
        self.add_new_block(new_block)
        for node in self.nodes:
            node.add_new_block(new_block)
        print('Process ends' + "\n")
        
    def announce_winner(self):
        self.blockChain.append(self.myCurrBlock)

    def add_new_block(self, block):
        if self.is_block_valid(block):
            #check index too
            self.blockChain.append(block)
            acct = block['Validator'].rsplit(', ')
            if self.myAccount['Address'] != acct[0]:
                self.myAccount['Age'] += 1
            else:
                self.myAccount['Weight'] += (randint(1, 10) * self.myAccount['Age'])
                self.myAccount['Age'] = 0
        self.tempBlocks = []
        self.myCurrBlock = {}
        self.validators = set()



    def _pos(self):
        print("Coming from ==========================> " + str(self.myAccount) + "\n")
        time.sleep(1)
        print('***Generating new stake block***' + "\n")
        time.sleep(1)
        self.generate_new_block()
        print('***Exchanging temporary blocks with other nodes***' + "\n")
        time.sleep(1)
        self.get_blocks_from_nodes()
        print('***Picking a winner***' + "\n")
        time.sleep(1)
        print("Winner is =======================> " + str(self.pick_winner()) + "\n")
    
    def resolve_conflict(self):
        for node in self.nodes:
            if len(node.blockChain) > len(self.blockChain):
                if self.is_chain_valid(node.blockChain):
                    print('***Replacing node***' + "\n")
                    self.blockChain = node.blockChain
                    return
        print('***My chain is authoritative***' + "\n")
        return

    def is_chain_valid(self, chain):
        _prevBlock = ''
        for block in chain:
            if self.is_block_valid(block, prevBlock=_prevBlock):
                _prevBlock = block
            else:
                return False
        return True


    def add_new_node(self, new_node):
        self.nodes.add(new_node)
        new_node.add_another_node(self)

    def add_another_node(self, another_node):
        self.nodes.add(another_node)

    @staticmethod
    def hasher(block):
        block_string = json.dumps(block, sort_keys=True).encode()
        return sha256(block_string).hexdigest()

    @staticmethod
    def get_validator(address):
        return ', '.join([address['Address'], str(address['Weight']), str(address['Age'])])

    def generate_genesis_block(self, genesisblock):
        address = {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
        address = self.get_validator(address)
        genesisblock['Index'] = 0 if not genesisblock['Index'] else genesisblock['Index']
        genesisblock['Timestamp'] = str(datetime.now()) if not genesisblock['Timestamp'] else genesisblock['Timestamp']
        genesisblock['BPM'] = 0 if not genesisblock['BPM'] else genesisblock['BPM']
        genesisblock['PrevHash'] = '0000000000000000'
        genesisblock['Validator'] = address if not genesisblock['Validator'] else genesisblock['Validator']
        genesisblock['Hash'] = self.hasher(genesisblock)
        return genesisblock

# %%
if {}:
    print("sa")

# %%
blockchain4.blockChain [-1]
# Out:
# {'Index': 16,
#  'Timestamp': '2022-07-11 10:02:47.328506',
#  'BPM': 62,
#  'PrevHash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77',
#  'Validator': 'account2, 106, 1',
#  'Hash': 'd2c9a3c7eb1fcac31c0e03b6e1e685277339377c80d3680293f0701ac22a5db1'}

# %%
"""Run test"""
account = {'Address': 'eltneg', 'Weight': 50}
account2 = {'Address': 'account2', 'Weight': 55}
account3 = {'Address': 'account3', 'Weight': 43}
account4 = {'Address': 'account4', 'Weight': 16}
blockchain = Blockchain(GENESIS_BLOCK, account)
blockchain.generate_new_block(52)

blockchain2 = Blockchain(GENESIS_BLOCK2, account2)
blockchain3 = Blockchain(GENESIS_BLOCK3, account3)

clients = [blockchain, blockchain2, blockchain3]

blockchain.add_new_node(blockchain2)
blockchain.add_new_node(blockchain3)

blockchain2.add_new_node(blockchain)
blockchain2.add_new_node(blockchain3)

blockchain.get_blocks_from_nodes()
blockchain2.get_blocks_from_nodes()

blockchain.pick_winner()
#check if temp blocks are same

blockchain.pos()
blockchain2.pos()
blockchain3.pos()

blockchain4 = Blockchain(GENESIS_BLOCK4, account4)
blockchain4.add_new_node(blockchain)
blockchain4.add_new_node(blockchain2)
blockchain4.add_new_node(blockchain3)
blockchain4.pos()
clients.append(blockchain4)
while True:
    print('============================================ \n\n')
    client = clients[randint(0, 3)]
    client.pos()
# Out:
# {'Address': 'eltneg', 'Weight': 50, 'Age': 0} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '0', 8.333333333333334]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '0', 8.333333333333334]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 55, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '0', 8.333333333333334]
#
# New Block ====> {'Index': 1, 'Timestamp': '2022-07-11 09:57:55.009344', 'BPM': 52, 'PrevHash': 'da6ecd0853a224f5bf611e91f06c648aae2e96ef5fe354f70bc0faddd74202b4', 'Validator': 'eltneg, 50, 0', 'Hash': '20cdad508a9b9777d172f54d352e21d9d942212ea0ccbb2f48e1e9d9a6f5db56'}
#
# Process ends
#
# {'Address': 'account2', 'Weight': 55, 'Age': 1} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 55, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '55', '1', 55]
#
# New Block ====> {'Index': 2, 'Timestamp': '2022-07-11 09:58:14.029059', 'BPM': 62, 'PrevHash': '20cdad508a9b9777d172f54d352e21d9d942212ea0ccbb2f48e1e9d9a6f5db56', 'Validator': 'account2, 55, 1', 'Hash': 'c6eb953708c7418142de0f63f3226c5a4784008e30e3c3f8b1cb4f49ab4102ff'}
#
# Process ends
#
# {'Address': 'account3', 'Weight': 43, 'Age': 2} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 62, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '2', 86]
#
# New Block ====> {'Index': 3, 'Timestamp': '2022-07-11 09:58:30.046714', 'BPM': 62, 'PrevHash': 'c6eb953708c7418142de0f63f3226c5a4784008e30e3c3f8b1cb4f49ab4102ff', 'Validator': 'account3, 43, 2', 'Hash': 'edba341db81ead5f8b39f580cf1df46b21beffd14101076676a14376154dc991'}
#
# Process ends
#
# {'Address': 'account4', 'Weight': 16, 'Age': 0} =======================> Getting Valid chain
#
# ***Replacing node***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 57, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 62, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '2', 100]
#
# New Block ====> {'Index': 4, 'Timestamp': '2022-07-11 09:58:47.068533', 'BPM': 62, 'PrevHash': 'edba341db81ead5f8b39f580cf1df46b21beffd14101076676a14376154dc991', 'Validator': 'eltneg, 50, 2', 'Hash': '7f1e3b2fadd095c5a7669449308dc3c10c3eb6223976e9cbfc0103bf05e7a494'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account2', 'Weight': 62, 'Age': 2} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 62, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '62', '2', 124]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 57, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '62', '2', 124]
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '62', '2', 124]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 68, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '62', '2', 124]
#
# New Block ====> {'Index': 5, 'Timestamp': '2022-07-11 09:59:06.086911', 'BPM': 62, 'PrevHash': '7f1e3b2fadd095c5a7669449308dc3c10c3eb6223976e9cbfc0103bf05e7a494', 'Validator': 'account2, 62, 2', 'Hash': 'bc0faaf8c05508024ba422fe9dd7ddcab1ebbb0c15a6f6b560ff162fe85d690c'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account3', 'Weight': 57, 'Age': 1} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 57, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '68', '1', 68]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '68', '1', 68]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 70, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '68', '1', 68]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 68, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '68', '1', 68]
#
# New Block ====> {'Index': 6, 'Timestamp': '2022-07-11 09:59:27.111565', 'BPM': 62, 'PrevHash': 'bc0faaf8c05508024ba422fe9dd7ddcab1ebbb0c15a6f6b560ff162fe85d690c', 'Validator': 'eltneg, 68, 1', 'Hash': '925480f9f2afb24f48e23ae8a56ebf34be0eb2c78ba8a3e01dea28544808c173'}
# Process ends
#
# ============================================
#
#
# {'Address': 'account3', 'Weight': 57, 'Age': 2} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 57, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '57', '2', 114]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '57', '2', 114]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 70, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '57', '2', 114]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 73, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '57', '2', 114]
#
# New Block ====> {'Index': 7, 'Timestamp': '2022-07-11 09:59:46.132190', 'BPM': 62, 'PrevHash': '925480f9f2afb24f48e23ae8a56ebf34be0eb2c78ba8a3e01dea28544808c173', 'Validator': 'account3, 57, 2', 'Hash': 'a673a91e409428397c151e090676c2ec31d5a1d7aacc6979e54888af2a31deaa'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'eltneg', 'Weight': 73, 'Age': 1} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 73, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '70', '2', 140]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 75, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '70', '2', 140]
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '70', '2', 140]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 70, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '70', '2', 140]
#
# New Block ====> {'Index': 8, 'Timestamp': '2022-07-11 10:00:07.154748', 'BPM': 62, 'PrevHash': 'a673a91e409428397c151e090676c2ec31d5a1d7aacc6979e54888af2a31deaa', 'Validator': 'account2, 70, 2', 'Hash': 'ebd201568f46cf7ba2f6afbe09fa62084de88d11495895af74edcab4754f9474'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account3', 'Weight': 75, 'Age': 1} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 75, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '73', '2', 146]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '73', '2', 146]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 78, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '73', '2', 146]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 73, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '73', '2', 146]
#
# New Block ====> {'Index': 9, 'Timestamp': '2022-07-11 10:00:27.176489', 'BPM': 62, 'PrevHash': 'ebd201568f46cf7ba2f6afbe09fa62084de88d11495895af74edcab4754f9474', 'Validator': 'eltneg, 73, 2', 'Hash': '19d3f9e7296a5634acd757da90646e5b973cf9dde18d7c40287f8e2ca916efa8'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'eltneg', 'Weight': 83, 'Age': 0} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 83, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '75', '2', 150]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 75, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '75', '2', 150]
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '75', '2', 150]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 78, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '75', '2', 150]
#
# New Block ====> {'Index': 10, 'Timestamp': '2022-07-11 10:00:47.198604', 'BPM': 62, 'PrevHash': '19d3f9e7296a5634acd757da90646e5b973cf9dde18d7c40287f8e2ca916efa8', 'Validator': 'account3, 75, 2', 'Hash': '1ae965ad29b0ac2a0129718055372f53c58dbbbdef645c54fb336fc1777968b0'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account4', 'Weight': 16, 'Age': 1} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '78', '2', 156]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 95, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '78', '2', 156]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 78, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '78', '2', 156]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 83, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '78', '2', 156]
#
# New Block ====> {'Index': 11, 'Timestamp': '2022-07-11 10:01:07.218673', 'BPM': 62, 'PrevHash': '1ae965ad29b0ac2a0129718055372f53c58dbbbdef645c54fb336fc1777968b0', 'Validator': 'account2, 78, 2', 'Hash': 'ef032cbc245c673a2b33b47e9c0e52d2a7d97ae300da2b5fe2b05f21aba224d6'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'eltneg', 'Weight': 83, 'Age': 2} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 83, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '83', '2', 166]
#
# ***Calling other nodes to announce theirs***
# Coming from ==========================> {'Address': 'account3', 'Weight': 95, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '83', '2', 166]
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '83', '2', 166]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 86, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '83', '2', 166]
#
# New Block ====> {'Index': 12, 'Timestamp': '2022-07-11 10:01:26.237654', 'BPM': 62, 'PrevHash': 'ef032cbc245c673a2b33b47e9c0e52d2a7d97ae300da2b5fe2b05f21aba224d6', 'Validator': 'eltneg, 83, 2', 'Hash': '11bcc83354c504ce9a7af9d45badb9cc38c00c415408a367038f12c317b6bd7b'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account3', 'Weight': 95, 'Age': 1} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 95, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '95', '1', 95]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '95', '1', 95]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 86, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '95', '1', 95]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 97, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '95', '1', 95]
#
# New Block ====> {'Index': 13, 'Timestamp': '2022-07-11 10:01:46.259050', 'BPM': 62, 'PrevHash': '11bcc83354c504ce9a7af9d45badb9cc38c00c415408a367038f12c317b6bd7b', 'Validator': 'account3, 95, 1', 'Hash': '38a5aec24d4635544746bc45ad8f7be347077b0098e8dbb052fc72148e5a69e5'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account4', 'Weight': 16, 'Age': 2} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '86', '2', 172]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 101, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '86', '2', 172]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 86, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '86', '2', 172]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 97, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '86', '2', 172]
#
# New Block ====> {'Index': 14, 'Timestamp': '2022-07-11 10:02:07.283204', 'BPM': 62, 'PrevHash': '38a5aec24d4635544746bc45ad8f7be347077b0098e8dbb052fc72148e5a69e5', 'Validator': 'account2, 86, 2', 'Hash': 'd670f5fa5b569878abb7238b068264930e156fb8560f2f7377dc081f2df9d7ea'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account4', 'Weight': 16, 'Age': 3} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 3}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '97', '2', 194]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 101, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '97', '2', 194]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 106, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '97', '2', 194]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 97, 'Age': 2}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '97', '2', 194]
#
# New Block ====> {'Index': 15, 'Timestamp': '2022-07-11 10:02:27.305631', 'BPM': 62, 'PrevHash': 'd670f5fa5b569878abb7238b068264930e156fb8560f2f7377dc081f2df9d7ea', 'Validator': 'eltneg, 97, 2', 'Hash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'eltneg', 'Weight': 111, 'Age': 0} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 111, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '106', '1', 106]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 101, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '106', '1', 106]
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 4}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '106', '1', 106]
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 106, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account2', '106', '1', 106]
#
# New Block ====> {'Index': 16, 'Timestamp': '2022-07-11 10:02:47.328506', 'BPM': 62, 'PrevHash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77', 'Validator': 'account2, 106, 1', 'Hash': 'd2c9a3c7eb1fcac31c0e03b6e1e685277339377c80d3680293f0701ac22a5db1'}
#
# Process ends
#
# ============================================
#
#
# {'Address': 'account2', 'Weight': 109, 'Age': 0} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account2', 'Weight': 109, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '111', '1', 111]
#
# ***Calling other nodes to announce theirs***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 101, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '111', '1', 111]
#
# Coming from ==========================> {'Address': 'account4', 'Weight': 16, 'Age': 4}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '111', '1', 111]
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 111, 'Age': 1}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '111', '1', 111]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1719321/1575806088.py in <module>
#      37     print('============================================ \n\n')
#      38     client = clients[randint(0, 3)]
# ---> 39     client.pos()
#
# /tmp/ipykernel_1719321/883035578.py in pos(self)
#     175         for node in self.nodes:
#     176             node._pos()
# --> 177         time.sleep(1)
#     178         for block in self.tempBlocks:
#     179             validator = block['Validator'].rsplit(', ')
#
# KeyboardInterrupt:

# %%
clients
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1718740/1914999197.py in <module>
# ----> 1 clients.blockChain
#
# AttributeError: 'list' object has no attribute 'blockChain'

# %%
blockchain4.blockChain
# Out:
# [{'Index': 0,
#   'Timestamp': '2022-07-11 09:57:54.772300',
#   'BPM': 0,
#   'PrevHash': '0000000000000000',
#   'Validator': 'eltneg, 50, 0',
#   'Hash': 'da6ecd0853a224f5bf611e91f06c648aae2e96ef5fe354f70bc0faddd74202b4'},
#  {'Index': 1,
#   'Timestamp': '2022-07-11 09:57:55.009344',
#   'BPM': 52,
#   'PrevHash': 'da6ecd0853a224f5bf611e91f06c648aae2e96ef5fe354f70bc0faddd74202b4',
#   'Validator': 'eltneg, 50, 0',
#   'Hash': '20cdad508a9b9777d172f54d352e21d9d942212ea0ccbb2f48e1e9d9a6f5db56'},
#  {'Index': 2,
#   'Timestamp': '2022-07-11 09:58:14.029059',
#   'BPM': 62,
#   'PrevHash': '20cdad508a9b9777d172f54d352e21d9d942212ea0ccbb2f48e1e9d9a6f5db56',
#   'Validator': 'account2, 55, 1',
#   'Hash': 'c6eb953708c7418142de0f63f3226c5a4784008e30e3c3f8b1cb4f49ab4102ff'},
#  {'Index': 3,
#   'Timestamp': '2022-07-11 09:58:30.046714',
#   'BPM': 62,
#   'PrevHash': 'c6eb953708c7418142de0f63f3226c5a4784008e30e3c3f8b1cb4f49ab4102ff',
#   'Validator': 'account3, 43, 2',
#   'Hash': 'edba341db81ead5f8b39f580cf1df46b21beffd14101076676a14376154dc991'},
#  {'Index': 4,
#   'Timestamp': '2022-07-11 09:58:47.068533',
#   'BPM': 62,
#   'PrevHash': 'edba341db81ead5f8b39f580cf1df46b21beffd14101076676a14376154dc991',
#   'Validator': 'eltneg, 50, 2',
#   'Hash': '7f1e3b2fadd095c5a7669449308dc3c10c3eb6223976e9cbfc0103bf05e7a494'},
#  {'Index': 5,
#   'Timestamp': '2022-07-11 09:59:06.086911',
#   'BPM': 62,
#   'PrevHash': '7f1e3b2fadd095c5a7669449308dc3c10c3eb6223976e9cbfc0103bf05e7a494',
#   'Validator': 'account2, 62, 2',
#   'Hash': 'bc0faaf8c05508024ba422fe9dd7ddcab1ebbb0c15a6f6b560ff162fe85d690c'},
#  {'Index': 6,
#   'Timestamp': '2022-07-11 09:59:27.111565',
#   'BPM': 62,
#   'PrevHash': 'bc0faaf8c05508024ba422fe9dd7ddcab1ebbb0c15a6f6b560ff162fe85d690c',
#   'Validator': 'eltneg, 68, 1',
#   'Hash': '925480f9f2afb24f48e23ae8a56ebf34be0eb2c78ba8a3e01dea28544808c173'},
#  {'Index': 7,
#   'Timestamp': '2022-07-11 09:59:46.132190',
#   'BPM': 62,
#   'PrevHash': '925480f9f2afb24f48e23ae8a56ebf34be0eb2c78ba8a3e01dea28544808c173',
#   'Validator': 'account3, 57, 2',
#   'Hash': 'a673a91e409428397c151e090676c2ec31d5a1d7aacc6979e54888af2a31deaa'},
#  {'Index': 8,
#   'Timestamp': '2022-07-11 10:00:07.154748',
#   'BPM': 62,
#   'PrevHash': 'a673a91e409428397c151e090676c2ec31d5a1d7aacc6979e54888af2a31deaa',
#   'Validator': 'account2, 70, 2',
#   'Hash': 'ebd201568f46cf7ba2f6afbe09fa62084de88d11495895af74edcab4754f9474'},
#  {'Index': 9,
#   'Timestamp': '2022-07-11 10:00:27.176489',
#   'BPM': 62,
#   'PrevHash': 'ebd201568f46cf7ba2f6afbe09fa62084de88d11495895af74edcab4754f9474',
#   'Validator': 'eltneg, 73, 2',
#   'Hash': '19d3f9e7296a5634acd757da90646e5b973cf9dde18d7c40287f8e2ca916efa8'},
#  {'Index': 10,
#   'Timestamp': '2022-07-11 10:00:47.198604',
#   'BPM': 62,
#   'PrevHash': '19d3f9e7296a5634acd757da90646e5b973cf9dde18d7c40287f8e2ca916efa8',
#   'Validator': 'account3, 75, 2',
#   'Hash': '1ae965ad29b0ac2a0129718055372f53c58dbbbdef645c54fb336fc1777968b0'},
#  {'Index': 11,
#   'Timestamp': '2022-07-11 10:01:07.218673',
#   'BPM': 62,
#   'PrevHash': '1ae965ad29b0ac2a0129718055372f53c58dbbbdef645c54fb336fc1777968b0',
#   'Validator': 'account2, 78, 2',
#   'Hash': 'ef032cbc245c673a2b33b47e9c0e52d2a7d97ae300da2b5fe2b05f21aba224d6'},
#  {'Index': 12,
#   'Timestamp': '2022-07-11 10:01:26.237654',
#   'BPM': 62,
#   'PrevHash': 'ef032cbc245c673a2b33b47e9c0e52d2a7d97ae300da2b5fe2b05f21aba224d6',
#   'Validator': 'eltneg, 83, 2',
#   'Hash': '11bcc83354c504ce9a7af9d45badb9cc38c00c415408a367038f12c317b6bd7b'},
#  {'Index': 13,
#   'Timestamp': '2022-07-11 10:01:46.259050',
#   'BPM': 62,
#   'PrevHash': '11bcc83354c504ce9a7af9d45badb9cc38c00c415408a367038f12c317b6bd7b',
#   'Validator': 'account3, 95, 1',
#   'Hash': '38a5aec24d4635544746bc45ad8f7be347077b0098e8dbb052fc72148e5a69e5'},
#  {'Index': 14,
#   'Timestamp': '2022-07-11 10:02:07.283204',
#   'BPM': 62,
#   'PrevHash': '38a5aec24d4635544746bc45ad8f7be347077b0098e8dbb052fc72148e5a69e5',
#   'Validator': 'account2, 86, 2',
#   'Hash': 'd670f5fa5b569878abb7238b068264930e156fb8560f2f7377dc081f2df9d7ea'},
#  {'Index': 15,
#   'Timestamp': '2022-07-11 10:02:27.305631',
#   'BPM': 62,
#   'PrevHash': 'd670f5fa5b569878abb7238b068264930e156fb8560f2f7377dc081f2df9d7ea',
#   'Validator': 'eltneg, 97, 2',
#   'Hash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77'},
#  {'Index': 16,
#   'Timestamp': '2022-07-11 10:02:47.328506',
#   'BPM': 62,
#   'PrevHash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77',
#   'Validator': 'account2, 106, 1',
#   'Hash': 'd2c9a3c7eb1fcac31c0e03b6e1e685277339377c80d3680293f0701ac22a5db1'}]

# %%
blockchain4.blockChain     [-1]
# Out:
# {'Index': 16,
#  'Timestamp': '2022-07-11 10:02:47.328506',
#  'BPM': 62,
#  'PrevHash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77',
#  'Validator': 'account2, 106, 1',
#  'Hash': 'd2c9a3c7eb1fcac31c0e03b6e1e685277339377c80d3680293f0701ac22a5db1'}

# %%
blockchain2.blockChain [-2]
# Out:
# {'Index': 15,
#  'Timestamp': '2022-07-11 10:02:27.305631',
#  'BPM': 62,
#  'PrevHash': 'd670f5fa5b569878abb7238b068264930e156fb8560f2f7377dc081f2df9d7ea',
#  'Validator': 'eltneg, 97, 2',
#  'Hash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77'}

# %%
blockchain2.blockChain [-3]
# Out:
# {'Index': 4,
#  'Timestamp': '2022-07-11 09:32:23.885832',
#  'BPM': 59,
#  'PrevHash': '4e6cdc70a17d935a36d18c4112b03ab50cbe005bc2e651b86830e41a9b571495',
#  'Validator': 'eltneg, 50, 2',
#  'Hash': 'a48a58a06271985bff2b6efb71c479d0547a2212516f45a5e952b91e6a409d8a'}

# %%
blockchain2.nodes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1719162/73183028.py in <module>
# ----> 1 blockchain2.nodes
#
# NameError: name 'blockchain2' is not defined

# %%
blockchain2.blockChain [-1]
# Out:
# {'Index': 16,
#  'Timestamp': '2022-07-11 10:02:47.328506',
#  'BPM': 62,
#  'PrevHash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77',
#  'Validator': 'account2, 106, 1',
#  'Hash': 'd2c9a3c7eb1fcac31c0e03b6e1e685277339377c80d3680293f0701ac22a5db1'}

# %%
blockchain2.blockChain [-1]
# Out:
# {'Index': 16,
#  'Timestamp': '2022-07-11 10:02:47.328506',
#  'BPM': 62,
#  'PrevHash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77',
#  'Validator': 'account2, 106, 1',
#  'Hash': 'd2c9a3c7eb1fcac31c0e03b6e1e685277339377c80d3680293f0701ac22a5db1'}

# %%
blockchain4.is_block_valid  (blockchain2.blockChain [-1] ,blockchain2.blockChain [-2] )
# Out:
# True

# %%
blockchain4

# %%
is_block_valid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1719321/344541484.py in <module>
# ----> 1 is_block_valid
#
# NameError: name 'is_block_valid' is not defined

# %%
for i in blockchain4.nodes:
    print(i.is_block_valid)
# Out:
# <__main__.Blockchain object at 0x7ff3d04ad880>
# <__main__.Blockchain object at 0x7ff3d04ad850>
# <__main__.Blockchain object at 0x7ff3d04ad8e0>

# %%
i.generate_new_block()['Validator']
# Out:
# 'eltneg, 111, 1'

# %%
i.is_block_valid(i.generate_new_block())
# Out:
# True

# %%
blockchain4.generate_new_block(52)
# Out:
# {'Index': 17,
#  'Timestamp': '2022-07-11 10:03:07.348474',
#  'BPM': 62,
#  'PrevHash': 'd2c9a3c7eb1fcac31c0e03b6e1e685277339377c80d3680293f0701ac22a5db1',
#  'Validator': 'account4, 16, 4',
#  'Hash': 'd3bb2757b5947d6e2fcd1f5b028e3702bebeb796de4dd5bc26dc5771336e52a4'}

# %%
blockchain4.blockChain[-1]
# Out:
# {'Index': 16,
#  'Timestamp': '2022-07-11 10:02:47.328506',
#  'BPM': 62,
#  'PrevHash': '00bbf0a95d3d6caf53280eaecb5262a4e286f1e6433f55d3fbdbe2f43a60de77',
#  'Validator': 'account2, 106, 1',
#  'Hash': 'd2c9a3c7eb1fcac31c0e03b6e1e685277339377c80d3680293f0701ac22a5db1'}

# %%
len(blockchain4.blockChain)
# Out:
# 17

# %%
"""Run test"""
account = {'Address': 'eltneg', 'Weight': 50}
account2 = {'Address': 'account2', 'Weight': 55}
account3 = {'Address': 'account3', 'Weight': 43}
account4 = {'Address': 'account4', 'Weight': 16}
blockchain.generate_new_block(52)
# Out:
# Invalid genesis block.
# OR
# Unable to verify block
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1718591/2647504478.py in <module>
#       5 account4 = {'Address': 'account4', 'Weight': 16}
#       6 blockchain = Blockchain(GENESIS_BLOCK, account)
# ----> 7 blockchain.generate_new_block(52)
#
# /tmp/ipykernel_1718591/3708306477.py in generate_new_block(self, bpm, oldBlock, address)
#      98         if self.myCurrBlock:
#      99             return self.myCurrBlock
# --> 100         prevHash = self.blockChain[-1]['Hash']
#     101         index = len(self.blockChain) if not oldBlock else oldBlock['Index'] + 1
#     102         address =  self.get_validator(self.myAccount) if not address else address
#
# IndexError: list index out of range

# %%
blockchain = Blockchain(GENESIS_BLOCK, account)

blockchain2 = Blockchain(GENESIS_BLOCK2, account2)
blockchain3 = Blockchain(GENESIS_BLOCK3, account3)

clients = [blockchain, blockchain2, blockchain3]

blockchain.add_new_node(blockchain2)
blockchain.add_new_node(blockchain3)

blockchain2.add_new_node(blockchain)
blockchain2.add_new_node(blockchain3)

blockchain.get_blocks_from_nodes()
blockchain2.get_blocks_from_nodes()

blockchain.pick_winner()
#check if temp blocks are same

blockchain.pos()
blockchain2.pos()
blockchain3.pos()

blockchain4 = Blockchain(GENESIS_BLOCK4, account4)
blockchain4.add_new_node(blockchain)
blockchain4.add_new_node(blockchain2)
blockchain4.add_new_node(blockchain3)
blockchain4.pos()
clients.append(blockchain4)
while True:
    print('============================================ \n\n')
    client = clients[randint(0, 3)]
    client.pos()

# %%
blockchain = Blockchain(GENESIS_BLOCK, account)

blockchain2 = Blockchain(GENESIS_BLOCK2, account2)
blockchain3 = Blockchain(GENESIS_BLOCK3, account3)

clients = [blockchain, blockchain2, blockchain3]
client = clients[randint(0, 3)]

client.pos()
# Out:
# Invalid genesis block.
# OR
# Unable to verify block
# {'Address': 'account3', 'Weight': 43, 'Age': 0} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'account3', 'Weight': 43, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['account3', '43', '0', 5.375]
#
# ***Calling other nodes to announce theirs***
#
# New Block ====> {'Index': 1, 'Timestamp': '2022-07-11 09:28:15.939256', 'BPM': 55, 'PrevHash': '91db784d0f4630343a33e6f06f70d3f970582740aaeab81515db5871718118a6', 'Validator': 'account3, 43, 0', 'Hash': '98151458d1420198e8b7a3f688b4377f2789b22696c90e4a16d8e6586a307039'}
#
# Process ends

# %%
blockchain = Blockchain(GENESIS_BLOCK, account)

blockchain2 = Blockchain(GENESIS_BLOCK2, account2)
blockchain3 = Blockchain(GENESIS_BLOCK3, account3)

clients = [blockchain, blockchain2, blockchain3]
client = clients[randint(0, 3)]

client.pos()
# Out:
# Invalid genesis block.
# OR
# Unable to verify block
# Invalid genesis block.
# OR
# Unable to verify block
# {'Address': 'eltneg', 'Weight': 50, 'Age': 0} =======================> Getting Valid chain
#
# ***My chain is authoritative***
#
# Coming from ==========================> {'Address': 'eltneg', 'Weight': 50, 'Age': 0}
#
# ***Generating new stake block***
#
# ***Exchanging temporary blocks with other nodes***
#
# ***Picking a winner***
#
# Winner is =======================> ['eltneg', '50', '0', 8.333333333333334]
#
# ***Calling other nodes to announce theirs***
#
# New Block ====> {'Index': 1, 'Timestamp': '2022-07-11 09:28:47.665343', 'BPM': 55, 'PrevHash': '91db784d0f4630343a33e6f06f70d3f970582740aaeab81515db5871718118a6', 'Validator': 'eltneg, 50, 0', 'Hash': 'fefe73b3c067d4b6194dda1426e832d556c192b2ea3bcdde4f169d5547acb68d'}
#
# Process ends
